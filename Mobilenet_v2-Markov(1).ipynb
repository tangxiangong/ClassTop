# %%
from IPython.display import clear_output
import os,cv2,random,torch,torchvision
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
AllClasses =['Markov','Non-Markov']

class DataProcess(torch.utils.data.Dataset):
    def __init__(self, ImagesPath, ImageTransformer):
        global AllClasses
        def GetImage(Class):
            images = [x for x in os.listdir(ImagesPath[Class]) if x[-3:].lower().endswith('jpg') or x[-3:].lower().endswith('png')]
            print(f'Found {len(images)} {Class} examples')
            return images
        
        self.images = {}
        self.Classes = AllClasses
        
        for Class in self.Classes:
            self.images[Class] = GetImage(Class)
            
        self.ImagesPath = ImagesPath
        self.ImageTransformer = ImageTransformer
    def __len__(self):
        return sum([len(self.images[Class]) for Class in self.Classes])
    def __getitem__(self, index):
        Class = random.choice(self.Classes)
        index = index % len(self.images[Class])
        NameOfPicture = self.images[Class][index]
        PathOfPicture = os.path.join(self.ImagesPath[Class], NameOfPicture)
        image = Image.open(PathOfPicture).convert('RGB')
        
        return self.ImageTransformer(image), self.Classes.index(Class)

def AccCalc(LabelsValues,OutputValues) : 
  _,PredictedValues = torch.max(OutputValues, 1)
  return sum((PredictedValues == LabelsValues).numpy())

# %%
AllImages = {}
SavedImages = 0
Path = 'F:/All Data\Data-classtop-Markov'
for folder in os.listdir(Path) : 
  ThisPath = os.path.join(Path,folder)
  AllImages[folder] = []
  for image in os.listdir(ThisPath) : 
    SavedImages+=1
    AllImages[folder].append(os.path.join(ThisPath,image))
AllImages
# Out:
# {'Markov': ['F:/All Data\\Data-classtop-Markov\\Markov\\1 (1).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (100).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (1000).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10000).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10001).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10002).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10003).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10004).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10005).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10006).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10007).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10008).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10009).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (1001).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10010).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10011).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10012).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10013).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10014).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10015).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10016).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10017).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10018).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10019).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (1002).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10020).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10021).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10022).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10023).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10024).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10025).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10026).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10027).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10028).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10029).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (1003).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10030).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10031).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10032).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10033).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10034).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10035).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10036).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10037).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10038).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10039).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (1004).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10040).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10041).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10042).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10043).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10044).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10045).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10046).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10047).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10048).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10049).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (1005).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10050).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10051).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10052).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10053).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10054).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10055).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10056).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10057).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10058).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10059).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (1006).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10060).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10061).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10062).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10063).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10064).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10065).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10066).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10067).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10068).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10069).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (1007).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10070).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10071).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10072).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10073).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10074).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10075).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10076).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10077).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10078).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10079).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (1008).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10080).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10081).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10082).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10083).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10084).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10085).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10086).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10087).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10088).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10089).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (1009).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10090).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10091).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10092).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10093).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10094).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10095).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10096).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10097).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10098).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10099).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (101).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (1010).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10100).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10101).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10102).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10103).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10104).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10105).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10106).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10107).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10108).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10109).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (1011).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10110).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10111).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10112).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10113).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10114).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10115).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10116).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10117).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10118).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10119).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (1012).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10120).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10121).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10122).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10123).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10124).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10125).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10126).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10127).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10128).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10129).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (1013).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10130).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10131).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10132).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10133).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10134).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10135).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10136).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10137).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10138).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10139).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (1014).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10140).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10141).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10142).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10143).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10144).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10145).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10146).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10147).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10148).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10149).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (1015).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10150).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10151).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10152).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10153).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10154).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10155).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10156).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10157).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10158).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10159).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (1016).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10160).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10161).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10162).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10163).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10164).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10165).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10166).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10167).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10168).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10169).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (1017).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10170).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10171).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10172).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10173).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10174).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10175).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10176).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10177).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10178).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (10179).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Markov\\1 (
jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1856).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1857).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1858).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1859).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (186).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1860).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1861).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1862).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1863).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1864).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1865).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1866).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1867).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1868).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1869).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (187).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1870).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1871).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1872).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1873).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1874).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1875).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1876).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1877).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1878).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1879).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (188).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1880).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1881).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1882).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1883).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1884).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1885).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1886).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1887).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1888).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1889).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (189).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1890).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1891).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1892).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1893).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1894).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1895).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1896).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1897).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1898).jpg',
#   'F:/All Data\\Data-classtop-Markov\\Non-Markov\\A (1899).jpg',
#   ...]}

# %%
len(AllImages.keys()),SavedImages
# Out:
# (2, 42000)

# %%
def ShowImages() : 
  global AllImages

  fig, ax = plt.subplots(2, 1, figsize=(64,64))  
  fig.tight_layout(pad=0.010)
  for i in range(len(ax)): 
    im = np.random.choice(AllImages[list(AllImages.keys())[i]])
    ax[i].imshow(plt.imread(im))
    ax[i].set_title(list(AllImages.keys())[i])

  plt.setp(plt.gcf().get_axes(), xticks=[], yticks=[])
ShowImages()

# %%
SavedImages,TrainingDataSize,TestingDataSize=0,0,0
ThisModel,ThisLossFunction ,ThisOptimizer = None,None,None
ThisTransformer = torchvision.transforms.Compose([torchvision.transforms.Resize(size=(50,50)),
                                                  #torchvision.transforms.RandomHorizontalFlip(),
                                                  torchvision.transforms.ToTensor()])

# %%
ImagesPath = {i:os.path.join(r'F:/All Data\Data-classtop-Markov',i) for i in AllClasses}

ProcessedData = DataProcess(ImagesPath, ThisTransformer)

TrainingDataSize = 0.80

TrainingSize = int(TrainingDataSize * len(ProcessedData))
TestingSize = len(ProcessedData) - TrainingSize

TrainingData, TestingData = torch.utils.data.random_split(ProcessedData, [TrainingSize, TestingSize])
TrainingDataSize,TestingDataSize=len(TrainingData), len(TestingData)
print("Length of train set   :  ", len(TrainingData))
print("Length of test set    :  ", len(TestingData))
# Out:
# Found 14000 Markov examples
# Found 28000 Non-Markov examples
# Length of train set   :   33600
# Length of test set    :   8400

# %%
BatchSize = 10

TrainingDataLength = torch.utils.data.DataLoader(TrainingData, batch_size = BatchSize, shuffle = True)
TestingDataLength = torch.utils.data.DataLoader(TestingData, batch_size=BatchSize, shuffle=True)


print("Length of training batches", len(TrainingDataLength))
print("Lentgth of test batches", len(TestingDataLength))
# Out:
# Length of training batches 3360
# Lentgth of test batches 840

# %%
SelectedModel  = torchvision.models.mobilenet v2(pretrained=True)
print(SelectedModel)
# Out:
# MobileNetV2(
#   (features): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (17): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (18): ConvNormActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1280, out_features=1000, bias=True)
#   )
# )

# %%
SelectedModel.fc = torch.nn.Linear(in_features=1280, out_features=2)
loss_fn = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(SelectedModel.parameters(), lr=0.00001)

# %%
# %%time
NumberOfEpochs = 30
ThisModel = SelectedModel
 
ThisOptimizer = optimizer

ThisLossFunction=loss_fn

AccuracyTraining,AccuracyTesting,LossTraining,LossTesting = [],[],[],[]
for j in range(NumberOfEpochs):
  print(j)
  TrainLoss,TestLoss,TrainAccuracy,TestAccuracy  = 0,0,0,0
  ThisModel.train()
  i=0
  for X,y in TrainingDataLength:
    i+=1
    ThisOptimizer.zero_grad()
    ThisOutput = ThisModel(X)
    ThisLoss = ThisLossFunction(ThisOutput,y)
    ThisLoss.backward()
    ThisOptimizer.step()
    TrainLoss += ThisLoss.item()
    TrainAccuracy += AccCalc(y,ThisOutput)
  TrainLoss /=i
  TrainAccuracy /=TrainingDataSize
  
  AccuracyTraining.append(TrainAccuracy)
  LossTraining.append(TrainLoss)
  
  ThisModel.eval()
  i=0
  for X,y in TestingDataLength:
    i+=1
    ThisOutput = ThisModel(X)
    ThisLoss = ThisLossFunction(ThisOutput,y)
    TestLoss += ThisLoss.item()
    TestAccuracy += AccCalc(y,ThisOutput)
  
  TestLoss/=i
  TestAccuracy /=TestingDataSize
  AccuracyTesting.append(TestAccuracy)
  LossTesting.append(TestLoss)
  
  clear_output(wait=True)
  print(f'For Epoch Number {j+1}')
  print('---------------------------------------------')
  print(f'Train Loss is {np.round(TrainLoss,2)} & Train Accuracy is {np.round(TrainAccuracy,2)} ')
  print(f'Test Loss is {np.round(TestLoss,2)} & Test Accuracy is {np.round(TestAccuracy,2)}')
  torch.save(ThisModel, f"F:/All Data\Data-classtop-Markov/mobilenet_v2.Markov.h5")
  plt.figure(figsize=(20,10))
  XValue = [k for k in range(j+1)]
  plt.subplot(1,2,1)
  plt.plot(XValue,AccuracyTraining,label='Train Acc')
  plt.plot(XValue,AccuracyTesting,label='Test Acc')
  plt.legend()
  plt.subplot(1,2,2)
  plt.plot(XValue,LossTraining,label='Train Loss')
  plt.plot(XValue,LossTesting,label='Test Loss')
  plt.legend()
  plt.show()
# Out:
# For Epoch Number 30
# ---------------------------------------------
# Train Loss is 0.0 & Train Accuracy is 1.0
# Test Loss is 0.0 & Test Accuracy is 1.0
# Wall time: 15h 34min 32s

# %%
ThisModel = torch.load('F:/All Data\Data-classtop-Markov/mobilenet_v2.Markov.h5')

# %%
i=0
AllYValue,AllOutput = [],[]
ThisModel.eval()
ThisLossFunction = torch.nn.CrossEntropyLoss()
TestLoss,TestAccuracy  = 0,0
for X,y in TestingDataLength:
  i+=1
  # if i ==50 : break
  if i%50==0 : print(i)
  ThisOutput = ThisModel(X)
  AllYValue.extend(y)
  _,PredictedValues = torch.max(ThisOutput, 1)
  AllOutput.extend([int(i) for i in PredictedValues])
  ThisLoss = ThisLossFunction(ThisOutput,y)
  TestLoss += ThisLoss.item()
  TestAccuracy += AccCalc(y,ThisOutput)
z=0
for a,b in zip(AllOutput,[int(i) for i in AllYValue]) : 
  if a==b : z+=1
z/len(AllOutput)
# Out:
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 0.9998809523809524

# %%
TestLoss/i,TestAccuracy/i*0.10
# Out:
# (0.0004826194265788109, 0.9998809523809524)

# %%
print(f'Model Accuracy is {np.round(TestAccuracy/i*0.10,2)} and loss is {np.round(TestLoss/i,2)}')
# Out:
# Model Accuracy is 1.0 and loss is 0.0

# %%
AllYValue = [int(i) for i in AllYValue]

# %%
from sklearn.metrics import classification_report,confusion_matrix
confusion_matrix(AllOutput,AllYValue)
# Out:
# array([[4211,    1],
#        [   0, 4188]], dtype=int64)

# %%
from sklearn.metrics import plot_confusion_matrix
import matplotlib.pyplot as plt
import itertools
import numpy as np

# %%
def plot_confusion_matrix(cm, target_names, title='Confusion matrix', cmap=None, normalize=True):


    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    fig= plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=85)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
            fig.savefig('confusion_matrix.eps')

# %%
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
conf_matrix = [[4211,    1],
       [   0, 4188]]
Calss_Names = ['Markov','Non-Markov']
plot_confusion_matrix(cm = np.array(conf_matrix),
                      normalize    = False,
                      target_names = Calss_Names,
                      title   ="Predicted label")
